# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Creating basic plots

# %%
np.random.randint(6,size=(5,))
# Out:
# array([2, 5, 4, 2, 5])

# %%
np.random.randint(6,size=(5,))
# Out:
# array([4, 1, 1, 2, 1])

# %% [markdown]
# * numpy random seed makes your code repeatable

# %%
np.random.seed(2)
np.random.randint(6,size=(5,))
# Out:
# array([0, 5, 0, 3, 2])

# %%
np.random.seed(2)
np.random.randint(6,size=(5,)) #if we give same seed number it gives the same output
# Out:
# array([0, 5, 0, 3, 2])

# %%
np.random.seed(3)
np.random.randint(6,size=(5,))  #otherwise different array
# Out:
# array([2, 0, 1, 3, 0])

# %%
np.random.seed(3)
np.random.randint(6,size=(5,))
# Out:
# array([2, 0, 1, 3, 0])

# %%
#make 4 sets
np.random.seed(2)
data1=np.linspace(0,2,100)
data2=data1**2
data3,data4=np.random.randn(2,100)

# %%
plt.plot(data1,data2)

# %%
plt.plot(data1,data2,label="quadratic")
plt.show()

# %%
plt.figure(figsize=(3,3))
plt.plot(data1,data2)

# %%
plt.figure(figsize=(3,5))
plt.plot(data1,data2)
plt.show()                     #3 is width,5 is height

# %%
plt.figure(figsize=(2,3))
plt.plot(data1,data2,'b+')
plt.show()

# %%
plt.figure(figsize=(10,10))
plt.plot(data1,data2,'ro')
plt.show()

# %%
plt.figure(figsize=(5,5))
plt.plot(data1,data2,'bo',label="quadratic")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(8,8))
plt.plot(data1,data2,'bo',label="quadratic")
plt.plot(data1,data2,'k-',label="black line")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(8,8))
plt.plot(data1,data2,'bo',label="quadratic")
plt.plot(data1,data2,'k-',label="black line")
plt.legend()
plt.title("data1 vls data2")
plt.xlabel("data1")
plt.ylabel("data2")
plt.show()

# %%
#initializing and fixing the size
plt.figure(figsize=(8,8))
#plotting
plt.plot(data1,data2,'bo',label="quadratic")
plt.plot(data1,data2,'k-',label="black line")
#display the legend
plt.legend()
#labeling
plt.title("data1 vls data2")
plt.xlabel("data1")
plt.ylabel("data2")
#keeping limit size
plt.xlim([0,1])
plt.ylim([0,1])
#annotating
plt.text(x=1,y=1,s="my plot ",color="black")
#display the plot
plt.show()

# %%
plt.figure(figsize=(5,5))
plt.plot(data1,data2)
plt.text(x=1,y=3,s="outliers",ha="left",color="blue")
plt.show()

# %%
plt.figure(figsize=(5,5))
plt.plot(data1,data2)
plt.text(x=1,y=3,s="outliers",ha="right",color="blue")
plt.show()

# %%
plt.figure(figsize=(5,5))
plt.plot(data1,data2)
plt.text(x=1,y=3,s="outliers",ha="center",color="blue")
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(5,5))
plt.plot(data1,data2)

plt.annotate("outliers",xytext=(1,3),xy=(2,3),arrowprops={},color="red")
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(5,5))
plt.plot(data1,data2,'ko')

plt.annotate("outliers",xytext=(1,3),xy=(2,3),fontsize=20,arrowprops={'arrowstyle':'->','connectionstyle':'arc3,rad=0.3'},color="red")
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(5,5))
plt.subplot(1,2,1)
plt.title("axis")
plt.plot(data1,np.log(data1),color="black")
plt.subplot(1,2,2)
plt.title("axes")
plt.plot(data1,np.exp(data1),color="red")
plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_12812\1985300405.py:4: RuntimeWarning: divide by zero encountered in log
#   plt.plot(data1,np.log(data1),color="black")

# %% [markdown]
# ## creating figure,adding axes,labeling axes

# %%
fig=plt.figure(figsize=(3,3))

# %%
#creating figure and adding axes
fig=plt.figure(figsize=(3,3),facecolor="lightskyblue")
ax=fig.add_subplot()

# %%
fig=plt.figure(figsize=(3,3),facecolor="lightskyblue")
ax=fig.add_subplot()
fig.suptitle("Figure")
ax.plot(data3,data4,'ko')
ax.set_title("axes",loc="right",fontsize="medium")
ax.set_xlabel("x axis")
ax.set_ylabel("y axis")
ax.grid(True)
ax.text(x=-2,y=3,s="out",color="red")
ax.set_facecolor("pink")

# %%
fig,axs=plt.subplots(5,6,figsize=(10,10),facecolor="red")

# %%
fig,axs=plt.subplots(2,2,figsize=(10,10),facecolor="red")
for ax in axs.ravel():
    ax.set_facecolor("yellow")

# %%
fig, ax = plt.subplots(figsize=(5, 2.7), layout='constrained')

ax.plot(data1, data1, label='linear', color='green')  # Plot some data on the axes
ax.plot(data1, data1**2, label='quadratic', color='orange')  # Plot more data on the axes...
ax.plot(data1, data1**3, label='cubic', color='blue')  # ... and some more

ax.set_title("Simple Plot")  # Add a title to the axes
ax.set_xlabel('x label')  # Add an x-label to the axes
ax.set_ylabel('y label')  # Add a y-label to the axes

ax.text(s="linear", x=1.75, y=2, color='green')
ax.text(s="quadratic", x=1.75, y=3.5, color='orange')
ax.text(s="cubic", x=1.75, y=5.2, color='blue')


ax.legend()  # Add a legend

plt.show()

# %%
# Make 4 random data sets

np.random.seed(2)
data1 = np.linspace(0, 100, 10000)
data2 = np.random.randint(1, 6, size=(10000, ))
data3, data4 = np.random.randn(2, 10000)

df = pd.DataFrame({"col_1": data1, 
                   "col_2": data2, 
                   "col_3": data3, 
                   "col_4": data4})

df.head()
# Out:
#       col_1  col_2     col_3     col_4
# 0  0.000000      1  1.045881  0.551947
# 1  0.010001      1 -1.098619 -2.139491
# 2  0.020002      4 -0.867764  1.419076
# 3  0.030003      3  0.889521 -1.309317
# 4  0.040004      4 -1.294830 -0.870633

# %%
#Univariate Plotting For Numerical Columns - Histogram and Box Plot
fig, axs = plt.subplots(1, 2, figsize=(6, 3), layout="constrained")
fig.suptitle("Univariate Plotting - Numerical Features")

axs[0].hist(df["col_3"])
axs[0].set_title("Histogram Plot", fontsize="medium")

axs[1].boxplot(df["col_3"])
axs[1].set_title("Box Plot", fontsize="medium")

plt.show()

# %%
fig, axs = plt.subplots(1, 2, figsize=(6, 3), layout="constrained")
fig.suptitle("Univariate Plotting - Categorical Features")

bar_plt_data = df["col_2"].value_counts()
axs[0].bar(bar_plt_data.index, bar_plt_data.values)
axs[0].set_title("Bar Plot", fontsize="medium")

bar_plt_data_normalized = df["col_2"].value_counts(normalize=True)
axs[1].pie(bar_plt_data_normalized.values, labels=bar_plt_data_normalized.index, autopct='%1.1f%%')
axs[1].set_title("Pie Plot", fontsize="medium")

plt.show()

# %%
fig, axs = plt.subplots(1, 3, figsize=(10, 3), layout="constrained")
fig.suptitle("Bivariate Plotting - Categorical Features")

axs[0].scatter(df["col_3"], df["col_4"])
axs[0].set_title("Scatter Plot", fontsize="medium")

hb1 = axs[1].hexbin(df["col_3"], df["col_4"])
axs[1].set_title("Hexbin Plot", fontsize="medium")
fig.colorbar(hb1, ax=axs[1])

hb2 = axs[2].hexbin(df["col_3"], df["col_4"], bins="log")
axs[2].set_title("Hexbin Plot with log Color Scale", fontsize="medium")
fig.colorbar(hb2, ax=axs[2])

plt.show()
